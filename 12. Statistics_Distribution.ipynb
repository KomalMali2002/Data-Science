# %% [markdown]
# # @ Gaussian Distribution :
#  - Gaussian Distribution is a countinuous probability whose PDF is Sysmmetric about mean
#  - x ------ contonuous random variable
#  - Gauncessian Distribution == normal distribution x ~ GD (mean , variance) whose probability desnsity function is bell shaped
#  - Distribution parameters --- means , variance
#
#  @ ex - Iris data set :
#  - PL -- Gaussian Distribution
#  - PL -- (means , variance ) --- PDF
#
# # @ skewness :
# - how far the distribution is from symmetric
# 1. left skewed (-ve skewed)
# 2. right skewed(+ve skewed)
# 3. symmetric
# - if the distribution is left or right skewed we have to convert it to the symmetric distribution(gaussian/normal)
# - for that we have to do the transformation
#
# 1. log transformation(right skewed): y=log(x) x=price prediction --->exp(y)
# 2. reciporcal transformation (right skewed): y=1/x prediction:1/y
# 3. squareroot transformation:(right skewed): y=sqrt(x) prediction:y^2
# 4. box cox transformation(right and left skewed)
#
# # @ Kurtosis :
# - How peak your distribution from the gaussian or normal distribution
#
# # @ Standardization :
# - transformation of the observation into the other observation for the better analysis
#
# # @ Standard normal variate :
# - z~N(0,1)
# - x~(mean,variace)---population
# - 50 observations[x1,x2----x50]
# - x1------->x1'=mean-x1/SD
# - x2------->x2'=mean-x2/SD
# - 50 observation----->new 50 observation
#
# # @ sampling distribution :
#
# - x ~ D(mean, variance)----D means any distribution it is non-gaussian distribution------>finite mean and finite variance
#
# - X is CRV which is fallows the non-gaussian having the distribution parameter mean and variance
#
#
# # @ DATA SET :
#  1. IRIS
#  2. PENGAIN
#  3. PIMA DIABETIE
#  4. LAPTOP --- PRICE
#  5. HABERMONS
#  6. TITANIC --- TRAIN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\New folder\\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.kdeplot(data=df,x=df["Age"],hue=df["Survived"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Important
# # @ Central Limit Theorem
# - central limit theorem says that the sampling distribution, with a finite mean and variance of a population where the sample mean equals to the population mean and sample variance tensed to the sigma or variance /n where n-->infinity
#
# - n>=30 distribution is guaranteed to converging towards distribution

# %%
df=pd.read_csv("D:\\Download\\iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data=df['petal.length']
sample_means=[]
sample_size=30
no_of_sample=1000
for i in range (no_of_sample):
    s=np.random.choice(data,size=sample_size,replace=True)
    sample_means.append(np.mean(s))

sns.histplot(sample_means,kde=True,color='red')
plt.title('CLT')
plt.xlabel("sampling distribution of petal length mean")
plt.ylabel('count')
plt.grid()
plt.show()

# %%
a=np.random.randint(1,1000)
a
# Out:
# 397

# %% [markdown]
# # @ quantile-quantile plot (Q-Q plot) :
# - it is used to check a variable is following the gaussian distribution or not
# - X ~ any distribution----RV
# - X=[x1,x2,x3-----x500]-----observation
# - step1: take all the observation and sort them in the ascending order.
# - step2: y~GD(meu,sigma)
# - step3: Plot Q-Q plot
# # @ SciPy : scientific python
# - import scipy.stats as stats
# - scipy ------>library name
# - stats------>module

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
#  - KDE is getting constructed using histogram

# %%
data = np.random.normal(loc=20, scale=5, size=1000)
stats.probplot(data, dist='norm', plot=plt)
plt.show()

# %%
data=np.random.uniform(low=1,high=1,size=10000)
stats.probplot(data,dist='norm',plot=plt)
plt.show()

# %%
#if we have small size then its hard to interpret the QQ plot
data=np.random.normal(loc=20,scale=5,size=50)
stats.probplot(data,dist='norm',plot=plt)
plt.show()

# %%
data=pd.read_csv("D:\\Download\\iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data=df["petal.length"]
stats.probplot(data,dist='norm',plot=plt)
plt.show()

# %%
#PW and PL is not following gaussian distribution 
data=df["petal.width"]
stats.probplot(data,dist='norm',plot=plt)
plt.show()

# %%
#SW and SL is not following gaussian distribution 
data=df["sepal.length"]
stats.probplot(data,dist='norm',plot=plt)
plt.show()

# %%
data=df["sepal.width"]
stats.probplot(data,dist='norm',plot=plt)
plt.show()

# %% [markdown]
# # @ CDF : Cumulative Distribution Function:
# - p(X<=x)
#
# - p(X=x)
#
# - p(x=180cm)
#
# - p(x>=180cm)
#
#   - step1 : Arrange them in the Ascending order
#   - step2 : Cumulative Frequency

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
Setosa=df[df['variety']=='Setosa']
Virginica=df[df['variety']=='Virginica']
Versicolor=df[df['variety']=='Versicolor']
sns.kdeplot(data=Setosa,x='petal.length',cumulative=True,label='Setosa')
sns.kdeplot(data=Virginica,x='petal.length',cumulative=True,label='Setosa')
sns.kdeplot(data=Versicolor,x='petal.length',cumulative=True,label='Setosa')
plt.title("cumulative distribution of PL")
plt.xlabel("petal.length")
plt.ylabel("probability")
plt.show()

# %%
Virginica=df[df['variety']=='Virginica']
sns.kdeplot(data=Virginica,cumulative=True)
# Out:
# <Axes: ylabel='Density'>

# %%
ersicolor=df[df['variety']=='Versicolor']
sns.kdeplot(data=Versicolor,x='petal.width',cumulative=True)
# Out:
# <Axes: xlabel='petal.width', ylabel='Density'>

# %% [markdown]
#  - median----->MAD(median absolute deviation)----it is used when we want to find average where outliers are present

# %% [markdown]
# # @ MAD(median absolute deviation)
# - when we have outliers in the columns in that case we cannot find the mean
#
# - because mean is influenced by the outliers
#
# - so we will find out the median
#
# - for median the spread/scale is MAD
#
# - MAD will tell how far the datapoints from the median
#
# - median of absolute deviation
#
#    - syntax :
#
#             from statsmodels import robust
#             robust.mad(column_name)
#
# # @ IQR : Inter - quartile range
#   - IQR=(75th percentile)-(25th percentile)
#
# # @ chebyshevs inequality : (** Important)
#   - X~GD(mean,SD)
#   - formula: ((meu-k(sigma)<X<(meu+k(sigma)))>1-1/k^2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
from statsmodels import robust

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
a=robust.mad(df[df['variety']=='Setosa']["sepal.length"])
b=robust.mad(df[df['variety']=='Versicolor']["sepal.length"])
c=robust.mad(df[df['variety']=='Virginica']["sepal.length"])
print("setosa: ",a)
print('Versicolor: ',b)
print('Virginica: ',b)
# Out:
# setosa:  0.29652044370112063
# Versicolor:  0.5189107764769608
# Virginica:  0.5189107764769608

# %%
a=robust.mad(df[df['variety']=='Setosa']['sepal.width'])
b=robust.mad(df[df['variety']=='Versicolor']['sepal.width'])
c=robust.mad(df[df['variety']=='Virginica']['sepal.width'])
print("setosa: ",a)
print('Versicolor: ',b)
print('Virginica: ',b)
# Out:
# setosa:  0.3706505546264005
# Versicolor:  0.29652044370112063
# Virginica:  0.29652044370112063

# %%
a=robust.mad(df[df['variety']=='Setosa']['petal.length'])
b=robust.mad(df[df['variety']=='Versicolor']['petal.length'])
c=robust.mad(df[df['variety']=='Virginica']['petal.length'])
print("setosa: ",a)
print('Versicolor: ',b)
print('Virginica: ',b)
# Out:
# setosa:  0.14826022185056031
# Versicolor:  0.5189107764769602
# Virginica:  0.5189107764769602

# %%
a=robust.mad(df[df['variety']=='Setosa']['petal.width'])
b=robust.mad(df[df['variety']=='Versicolor']['petal.width'])
c=robust.mad(df[df['variety']=='Virginica']['petal.width'])
print("setosa: ",a)
print('Versicolor: ',b)
print('Virginica: ',b)
# Out:
# setosa:  0.0
# Versicolor:  0.2223903327758403
# Virginica:  0.2223903327758403

# %%
mean=df['petal.length'].mean()
mean
# Out:
# np.float64(3.7580000000000005)

# %%
std=df['petal.length'].std()
std
# Out:
# np.float64(1.7652982332594662)

# %% [markdown]
# #  methods but no formulation ----> to tell the distribution is gaussian or not
# - it is completely try and insert process their is no formula for checking distribution
# 1. Visualization ways: a. KDE------>PDF (histogram)--->distplot b. QQ plot: if sample size is less is hard to interpret the QQ plot.
# 2. Hypothesis testing: a. KS test b. Anderson daring test
#
# # @ Uniform Distribution :
# - equiprobable events or equally likely events
# - if the outcomes are having the equal chances of happening then that distribution generally a uniform distribution
# - each outcome have uniform or exactly same value
# - ex : rolling a die getting probability
#
#        getting(1)=1/6
#        getting(2)=1/6
#        getting(3)=1/6
#        getting(4)=1/6
#        getting(5)=1/6
#        getting(6)=1/6----equally likely ----uniform distribution
#
# - ex. rolling a two die and getting a sum----not equally likely event so not following the uniform distribution
#
# # @ Random Variable :
# - Discreate RV
# - Continuous RV
#           - based on the RV uniform Distribution are classified into 2 types
#
# # 1. Discreate uniform Distribution :
# - RV-------disc rete value
#
# - PMF-------probability mass function
#
# - X~DUD(a,b)
#
#          a and b are the distribution parameter
#          a----->lower outcome value
#          b----->upper outcome value
#          n=b-a+1------>no. of outcomes
#
#          ex : rolling a die
#
#               a=1  b=6------>n=6-1+1=6--------total no. of outcomes
#  # @ PMF-------probability mass function
#               p(X=xi)
# - if it is in arithmetic form then it is normal mean and if it is not then it is expected mean
#
#             mean=expected value=X*p(x)=(1+2+3+4+5+6)/6
#             E(x)=3.5
#             variance =
#
# # 2. Continuous Uniform Distribution :
#   - Continuous RV:
#
#   - Probability density function :
#
#     PDF=1/(b-a)   a<=x<=bb
#   - mean=expected value
#
# # **Important Interview Questions
#
# # Q. ex. rolling a die probability of getting a prime number is uniform distribution?
# - it is not a uniform distribution, because ---->if the probability of prime number is renormalized into the subset of prime number such as {2,3,5} then in this case all the three outcomes are Queally likely and they are uniformly distributed but the total sample space of die this events are not a equally likely so rolling a die and getting a prime number is not a uniform distribution
#
# # Q. when to count expected value or normal mean in uniform distribution?
# - mean in case of uniform distribution =(a+b/2)
# - but if the nature of the random variable is in arithmetic progression then the mean of uniform distribution will be expected value and if the it is not in arithmetic progression then the mean will be arithmetic mean
#
# - Log normal distribution :
#            - X~log normal distribution(mean,SD) then log(x) is follows the GD
#
# # @ How to check X follows lognormal distribution or not
# - X--->x1,x2,x3-------xn----->log normal distribution then
# - Y1=log(x1), Y2=log(x2)---------Yn=log(xn)------>if it is following gaussian distribution then we can say thet X follows the log normal distribution
# - used QQ plot to check GD!
# - BLog---uber---->AI ,paper with code
#    - data=np.random.lognormal
#    - np.log(data)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm

# %%
np.random.randint(30,60)
# Out:
# 50

# %%
# Approch of the Analysis the data
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# How many rows or colums
df.shape
# Out:
# (150, 5)

# %%
print(df.columns)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# count the veriety
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.arange(1, 7)
cdf = np.arange(1, len(data) + 1) / len(data)

plt.step(data, cdf, where='post')
plt.xlabel('x')
plt.ylabel('CDF')
plt.title('CDF of Discrete Uniform Distribution (Die Roll)')
plt.grid(True)
plt.show()

# %%
np.mean(a)
# Out:
# np.float64(148.0)

# %%
data=[20,40,60,80,100]
b=np.random.choice(data,size=5,replace=False)
np.mean(b)
# Out:
# np.float64(60.0)

# %% [markdown]
#  - Todays works analysis the iries data set

# %% [markdown]
#  - 5/5/2025

# %% [markdown]
#  - Important
#  - Central limit theorm
#  - Uniform Distribution
#
# # @ Interview Question : IMP
#
#  #  Q Rolling a die probability of getting a prime number :
#  - --- > It is not a uniform distribution , bcoz -- if the probability of prime number is renormalized into the subset of prime number such as {2,3,5}
#          then in this case all the three outcomes are equally likely and they are uniformly distributed but the total sample space of die this events
#          are not equally likey so rolling a die and getting a prime number is not uniform distribution.
#
#  - EX
#  - Rolling a die --- >
#  - x~DUD (a,b)
#  - a -- > Lowest outcome value
#  - b -- > highest outcome value
#  - n=b-a+1 -- > total number of outcomes
#  - PMF = Probability Mass Function
#  - p (X = Xi)

# %% [markdown]
# # @ Continuous Uniform Distribution :
#
#  - RV --> Continuous
#  - mean in case of uniform distribution = (a+b)/2
#  - but if the nature of the random variable is in Arithmatic Progression then the mean of uniform distribution will be expected value
#    and if it is not in Arithmatic Progression then the mean will be aritmatic mean
#  - mean  = Expected value

# %%
a = np.random.uniform(low=10,high=20,size=100)
a
# Out:
# array([16.32692491, 19.12370897, 16.89455659, 11.81747816, 18.92288186,
#        12.23993289, 18.5312603 , 19.22301279, 17.91580148, 12.41039725,
#        15.88665995, 13.29570201, 12.8521462 , 16.15700321, 10.07022272,
#        16.44877999, 18.61720684, 12.35920451, 14.98018272, 14.76170414,
#        18.78620021, 19.77691221, 13.15107447, 18.7084299 , 10.31311449,
#        12.57396175, 10.79305898, 12.53368108, 17.50270246, 16.96544906,
#        19.97796479, 17.76816191, 17.07351356, 14.88181288, 16.94385544,
#        11.98292723, 13.30941504, 16.5515849 , 10.86459145, 15.88941117,
#        17.67821991, 19.97857444, 14.81242739, 18.51596847, 17.11163923,
#        11.33941141, 16.77878497, 12.62129524, 15.18654489, 12.7501049 ,
#        16.03931263, 14.74308739, 16.84188861, 11.33124093, 12.89852493,
#        10.66450126, 18.93086902, 13.1188555 , 16.40252894, 13.31414008,
#        13.64605192, 10.81030157, 15.32466554, 13.66523477, 14.12244421,
# ...

# %% [markdown]
#  - BLog :
#  - uber AI
#  - Paper with code

# %% [markdown]
#  # Log Normal Distribution :
#  # Q How to check a Distribution log  normal or not ?
#  - -- >  - X~ Log normal Distribution (mean.SD)
#          - log (x) is following the Gaussian Distribution
#
#  # Q How to check X Follows log normal Distribution ?
#  - x --> X1,X2---------- Xn Log normal distribution

# %% [markdown]
#  - 7/05/2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
m=1
sd=0.5
a=np.random.lognormal(mean=m,sigma=sd,size=100)
sns.histplot(a,kde='True',color='red')
# Out:
# <Axes: ylabel='Count'>

# %%
log_val=np.log(a)
sns.histplot(log_val,kde=True,color='blue')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# - 14/5/2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# - Pareto Distribution (wikkipedia)

# %% [markdown]
# # @ Important Questions
# 1. Pareto Distribuction
# 2. Log log plot
# 3. Q-Q plot
# 4. Box cox
# 4. Tranfermation
# 5. Gaussian Distribution
# 6. how to check it is pareto distribution ----- log-log plot, Q-Q plot
# 7. how to analysis----to convert it in gaussian using box-cox transformation

# %% [markdown]
# # @ Power Law Distribution
#
#  - It is following the 80-20 rule
#  - The distribution which follows the power law we called it as pareto disctribution
#  - We have two distribution parameter
#  - (alpha --- scale/ mean)
#  -  (Xm ---> SD)
#  - CDF = p (X<x)
#  - CCDF = P (X>x) ----- complement cumulative distribution function

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from statsmodels import robust

# %% [raw]
# a=np.random.parato

# %%
data = [23,45,67,89,90,101,102]

# %%
stats.probplot(data, dist='pareto', sparams=(2.5,), plot=plt)
plt.show()

# %%
stats.probplot(data,dist='pareto',sparams=(1.2,),plot=plt)
plt.show()

# %%
stats.probplot(data, dist='pareto', sparams=(9.5,), plot=plt)
plt.show()

# %%
data=np.sort([23,45,67,89,90,101,102])
cdf= np.arange(1, len(data) + 1) / len(data)
ccdf=1-cdf
plt.loglog(data, ccdf, marker='o', linestyle='-', color='b')
plt.show()

# %%
data = [23, 45, 67, 89, 90, 101, 102]
sorted_data = np.sort(data)
cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
ccdf = 1 - cdf
plt.figure()
plt.step(sorted_data, ccdf, where='post', label='Empirical CCDF')
plt.xlabel('x')
plt.ylabel('P(X > x)')
plt.title('Empirical CCDF')
plt.grid(True)
plt.legend()
plt.show()

# %%
data = [23, 45, 67, 89, 90, 101, 102]
sorted_data = np.sort(data)
cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
ccdf = 1 - cdf
nonzero_indices = ccdf > 0
x = sorted_data[nonzero_indices]
y = ccdf[nonzero_indices]
plt.loglog(x, y, marker='o', linestyle='-', label='Empirical CCDF')
plt.xlabel('Data (log scale)')
plt.ylabel('CCDF (log scale)')
plt.title('Log-Log Plot of Empirical CCDF')
plt.legend()
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# # @ boxcox transformation :
# - X~pareto distribution(alpha,Xm)
#
#   x1,x2,x3-----xn------pareto
# - Y~GD(mean,sigma)
#
#   y1,y2,y3-------yn------gaussian
#
# - import scipy.stats as stats
# - Syntax:stats.boxcox(x)------>lambda
#
# - y1=((x1^lambda)-1)/lambda when lambda>0
#
# - log(x)-----lambda=0
#
# - when the lambda=0 then x follows the log normal distribution

# %%
15/5/2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
a=np.random.pareto(2,5)
a
# Out:
# array([1.67008249, 0.37679221, 0.76890217, 0.15284182, 0.21937162])

# %%
data = np.random.gamma(shape=2, scale=2, size=100)
sns.histplot(data, kde=True, color='red')
plt.show()

# %%
t_data,lam=stats.boxcox(data)

# %%
sns.histplot(t_data,kde=True ,color='blue')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # **Important all transformation:log,recipocal,square
# # ***Gaussian distribution

# %% [markdown]
# # @ Weilbull Distribution
#  - It is a non gaussian distribution.
#  - the distribution parameters are lambda(mean) k (SD).
#  - To convert weibull distribution into gaussian we can use the boxcox transformation.

# %% [markdown]
# # @ Gamma Distribution
#  - It is also follows the power law.
#  - It is non gaussian as well pareto.
#  - the distribution parameter for gamma is alpha (mean) and theta(SD).

# %% [markdown]
#  - API - Application Programming Interface

# %% [markdown]
# - HTTP is a Protocol
# - HTTP is not a API

# %%
! pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
response = requests.get("https://in.search.yahoo.com/search?fr=mcafee&type=E210IN1589G0&p=amazon+reviews")
print(response)
# Out:
# <Response [500]>

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
# ...

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
response.text
# Out:
# ''

# %% [raw]
# # Extract all the uris
# # remove tops get the text
