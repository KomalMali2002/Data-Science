# %% [markdown]
# # @ Data Visualization :
#
#                       - To undrstand the data in a better way.
#                       - Plotting is the most important thing in the data visualization.
#
# # @ Data Visualization Library :
#    1. Matplotlib
#    2. seaborn
#    3. plotly
#    4. d3.js
#
#
# # 1 Matplotlib :
#
#                - It is core data visualization library in python.
#                - Remaining all the libraries are built on the top pf matplotilb.
#                - Matplotlib is a kind of abstraction to other library.
#                - Syntax : matplotlib.pyplot as plt
#                - matplotlib : DV library name
#                - pyplot : It is a submodule present in the matplotlib  : It is using the core functionality of MATLAB for a plotting
#                - plt--alias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\Download\\laptop_data.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df["Company"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %% [markdown]
# # 2. Seaborn :
#
#             - It is also DV library which is build on the of matplolib
#             - Seaborn is kind of advanced version of matplotlib
#             - So whatever the things matplotplotlib is doing same thing seaborn will do in a better way
#             - Syntax : import seaborn as sns
#
# -  When we are constructing the line plot using matplotlib and it we are passing single axis measures then by default it sis considered as y-axis          measure and x-axis measures is generated by matplotlib (it as starting from 0 becoz list index starts from 0)

# %%
sns.distplot(df["Price"])
plt.show()
# Out:
# C:\Users\Komal prakash mali\AppData\Local\Temp\ipykernel_1196\3178995481.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y)

# %%
plt.plot([1,2,3,4,5])
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.show()

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.title("plot between x vs y")
plt.xlabel("numbers")
plt.ylabel("squares")
plt.plot(x,y)

# %%
plt.plot([2,4,5,6,7])
plt.ylabel("y_axis")
plt.xlabel("x_axis")
plt.title("plot")
plt.show()

# %%
plt.plot([2,4,9,16,25])
plt.xlabel ("sqaure")
plt.ylabel("indexs")
plt.show()

# %%
plt.plot([2,4,9,16,25],[1,2,3,4,5])
plt.xlabel ("sqaure")
plt.ylabel("indexs")
plt.show()

# %%
a = [1,2,3,4,5]
b = [2,4,6,8,10]
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("title of a graph")
plt.grid()
plt.plot(a,b)

# %%
a = [1, 2, 3, 4]
b = [1, 4, 9, 16]
sns.lineplot(x=a, y=b)
plt.xlabel("x_axis")  
plt.ylabel("y_axis") 
plt.show()

# %% [markdown]
#  @ Barplot : Categorial columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
df ["Cpu"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cpu'>

# %%
df ["Cpu"].value_counts().plot(kind="bar")
plt.xticks(rotation ="vertical")
plt.show()

# %%
df["OpSys"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
a = [1, 2, 3, 4, 5]
b = [6, 7, 8, 9, 10]
plt.bar(a, b)
plt.show()

# %%
a = ['A', 'B', 'C', 'D']
b = [10, 15, 7, 12]
sns.barplot(x=a, y=b)
plt.show()

# %% [markdown]
# # 3 Scatterplot :
#
#                - We are drawing the scatter plot for two numerical columns
#                - It is kind of corealation graph
#                - Whenever we want to check the relationship between two columns then we will see the scatter plot

# %%
diameter=[2,3,4.5,6,8]
height=[3,4.5,6.7,8,9]
plt.scatter(diameter,height)

# %%
diameter=[2.7,3.4,2.9,6.7]
height=[2.4,3.7,4.1,3.0]
plt.scatter (diameter,height)
plt.show()

# %%
import numpy as np

# %%
x=np.array([2,3,4,5,6])
y=np.array([2,5,6,7,8])
plt.plot(x,y,linewidth=5.0)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\Download\\laptop_data.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %%
df ["Company"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
df1=pd.read_csv("D:\\Download\\iris.csv")
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=df1["sepal.length"],y=df1["sepal.width"])
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %%
sns.scatterplot(x=df1["petal.length"],y=df1["petal.width"])
# Out:
# <Axes: xlabel='petal.length', ylabel='petal.width'>

# %%
sns.scatterplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
#  @ Countplot :
#
#             -  It is used to visualize the categories and frequency count
#             - sns. countplot()

# %%
data=pd.DataFrame ({
    "category":['A','B','C','D','E'],
    "count":[400,500,700,1000,800]
})
data
# Out:
#   category  count
# 0        A    400
# 1        B    500
# 2        C    700
# 3        D   1000
# 4        E    800

# %%
sns.countplot(x=data["category"],data=data)
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
sns.countplot(x=df["Company"],data=data)
# Out:
# <Axes: xlabel='Company', ylabel='count'>

# %% [markdown]
# # @ Distribution plot :
#
#   1. boxplot : - It is used to visualized the distribution of a ddata and outliers
#               - sns.boxplot(x="category",y="values",data=df)
#
#   2. histogram :
#   3. KDE (kernel density estimate) :
#   4. violin plot :
#   5. distplot :

# %%
dff=pd.DataFrame({
    "category":["A","A","B","B","A","B","C"],
    "values":[11,21,12,14,16,34,28]
})

# %%
sns.boxplot(x='category',y='values',data=dff)
# Out:
# <Axes: xlabel='category', ylabel='values'>

# %%
df1=pd.read_csv("D:\\Download\\iris.csv")
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(kind="scatter", x="sepal.length", y="sepal.width")
plt.show()

# %% [markdown]
# - sepal length in this dataset varies from 4 to 8
# - sepal width is this dataset varies from 2 to 4.5

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df1,hue='variety',height=4).map(plt.scatter ,'sepal.length',"sepal.width").add_legend();
plt.show()

# %% [markdown]
# - iris setosa is somewhat seperable while virginica and versicolor are overlapping

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df1,hue='variety',height=4).map(plt.scatter ,'petal.length',"petal.width").add_legend();
plt.show()

# %% [markdown]
#  - If petal length is greater than or eqaul to 0.8 and petal length  is less than or eqaul to 2
#
#  - If (PL>=0.8 and PL<=2) and (PW>=0.2 and PW<=0.6)-------iris setosa
#
#  - If petal width is greater than or eqaul to 0.8 and petal width  is less than or eqaul to 2

# %% [markdown]
#  -  If (PL>=2.8 and PL<=3.3) and (PW>=0.8 and PW<=1.7)-------iris versicolor
#
#  - If (PL>=4.5 and PL<=6.9) and (PW>=1.4 and PW<=2.6)-------iris virginica

# %%
sns.pairplot(df1,hue="variety",size=3,diag_kind='kde')
plt.show()
# Out:
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df1,hue='variety',height=3).map(sns.distplot,'sepal.length').add_legend();
plt.show()
# Out:
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df1,hue='variety',height=3).map(sns.distplot,'sepal.width').add_legend();
plt.show()
# Out:
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df1,hue='variety',height=3).map(sns.distplot,'petal.length').add_legend();
plt.show()
# Out:
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df1,hue='variety',height=3).map(sns.distplot,'petal.width').add_legend();
plt.show()
# Out:
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Komal prakash mali\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# -  PL far better than PW and it is better then SL and SL is better than SW
# -  PL>>PW>>SL>>SW

# %%
sns.boxplot(x="variety", y="sepal.length", data=df1)
plt.show()

# %% [markdown]
# - (SL>=4.3 and SL<=5.8)----for setosa
# - (SL>=4.9 and SL<=7.0)-----for versicolor
# - (SL>=5.6 and SL<=7.9)-----for virginica-----it has outliers

# %%
sns.boxplot(x="variety", y="sepal.width", data=df1)
plt.show()

# %% [markdown]
# - (SW>=2.9 and SW<=4.3)----for setosa-----it has outliers
# - (SW>=2.0 and SW<=3.4)---for versicolor
# - (SW>=2.5 and SW<=3.6)-----for virginica----it has outliers

# %%
sns.boxplot(x="variety", y="petal.length", data=df1)
plt.show()

# %% [markdown]
# - (PL>=1.2 and PL<=1.7)----for setosa----it has outliers
# - (PL>=3.3 and PL<=5.1)-----for versicolor----it has outliers
# - (PL>=4.5 and PL<=6.9)-----for virginica

# %%
sns.boxplot(x="variety", y="petal.width", data=df1)
plt.show()

# %% [markdown]
# - (PW>=0.1 and PW<=0.4)----for setosa-----it has outliers
# - (PW>=1.0 and PW<=1.8)---for versicolor
# - (PW>=1.4 and PW<=2.5)-----for virginica

# %%
df1[['sepal.length' ,'sepal.width' , 'petal.length', 'petal.width']].mean()
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64

# %%
df1[['sepal.length' ,'sepal.width' , 'petal.length', 'petal.width']].std()
# Out:
# sepal.length    0.828066
# sepal.width     0.435866
# petal.length    1.765298
# petal.width     0.762238
# dtype: float64

# %%
df1.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.groupby("variety")["sepal.length"].describe()
# Out:
#             count   mean       std  min    25%  50%  75%  max
# variety
# Setosa       50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Versicolor   50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Virginica    50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
df1.groupby("variety")["sepal.width"].describe()
# Out:
#             count   mean       std  min    25%  50%    75%  max
# variety
# Setosa       50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# Versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
df1.groupby("variety")["petal.length"].describe()
# Out:
#             count   mean       std  min  25%   50%    75%  max
# variety
# Setosa       50.0  1.462  0.173664  1.0  1.4  1.50  1.575  1.9
# Versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# Virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
df1.groupby("variety")["petal.width"].describe()
# Out:
#             count   mean       std  min  25%  50%  75%  max
# variety
# Setosa       50.0  0.246  0.105386  0.1  0.2  0.2  0.3  0.6
# Versicolor   50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Virginica    50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5

# %% [markdown]
# - EDA Haberman’s Cancer Survival Dataset
